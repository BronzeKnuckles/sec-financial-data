# %%
import requests, zipfile, io
url = f"https://www.sec.gov/files/dera/data/financial-statement-data-sets/2024Q2.zip"
r = requests.get(url)

# %%
r.status_code
# Out:
# 404

# %%
import pandas as pd
import os

# %%
fname = "./data"


f = ["num","pre","sub","tag"]

for i in f:
    df = pd.read_csv(f'{fname}/{i}.txt',sep='\t', header=None)
    df.to_csv(f'{fname}/{i}.csv', header= None)
    print(f"Converted-- {fname}/{i}.csv")
    os.remove(f'{fname}/{i}.txt')
    os.remove(f'{fname}/readme.htm')
# Out:
# C:\Users\srive\AppData\Local\Temp\ipykernel_15220\3085970009.py:7: DtypeWarning: Columns (4,5,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{fname}/{i}.txt',sep='\t', header=None)
# Converted-- ./data/num.csv
# C:\Users\srive\AppData\Local\Temp\ipykernel_15220\3085970009.py:7: DtypeWarning: Columns (1,2,4,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{fname}/{i}.txt',sep='\t', header=None)
# Converted-- ./data/pre.csv
# C:\Users\srive\AppData\Local\Temp\ipykernel_15220\3085970009.py:7: DtypeWarning: Columns (1,3,19,21,23,24,26,27,29,31,32,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'{fname}/{i}.txt',sep='\t', header=None)
# Converted-- ./data/sub.csv
# C:\Users\srive\AppData\Local\Temp\ipykernel_15220\3085970009.py:7: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df = pd.read_csv('./data/2023q1/num.txt',sep='\t', header=None)
df.to_csv('./data/2023q1/num.csv', header=None)

df = pd.read_csv('./data/2023q1/pre.txt',sep='\t', header=None)
df.to_csv('./data/2023q1/pre.csv', header=None)

df = pd.read_csv('./data/2023q1/sub.txt',sep='\t', header=None)
df.to_csv('./data/2023q1/sub.csv', header=None)

df = pd.read_csv('./data/2023q1/tag.txt',sep='\t', header=None)
df.to_csv('./data/2023q1/tag.csv', header=None)

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/2018q2/tag.csv")
df["tlabel"]
# Out:
# 0                                          Entity [Domain]
# 1                                      Legal Entity [Axis]
# 2                                      Entity Public Float
# 3                               Document Fiscal Year Focus
# 4                                 Document Period End Date
#                                ...
# 84600    Temporary Equity Redeemable Noncontrolling Int...
# 84601                                    Total Fee Revenue
# 84602    Total Revenues Including Revenue Generated By ...
# 84603                                     Total Securities
# 84604                                    Treasury Services
# Name: tlabel, Length: 84605, dtype: object

# %%
start_year = 2009
end_year = 2023


print(f"\n\n\n DONE. \n\t From: {start_year}\n\t To: {end_year}\n\n\n")
# Out:
#  DONE.
# 	 From: 2009
# 	 To: 2023

# %%
import os
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# PostgreSQL connection parameters
DATABASE_URL = "postgresql://postgres:root@localhost:5432/sec-financial-data"

# Create a connection to the PostgreSQL database
engine = create_engine(DATABASE_URL)

# %%
import os
import psycopg2

# PostgreSQL connection parameters
DB_NAME = "sec-financial-data"
DB_USER = "postgres"
DB_PASS = "root"
DB_HOST = "localhost"
DB_PORT = "5432"

# Base directory containing subdirectories with CSV files
BASE_DIR = "./data/"

# Connect to the PostgreSQL database
"""conn = psycopg2.connect(
    dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=DB_HOST, port=DB_PORT
)
cur = conn.cursor()"""

# Loop through each subdirectory and then each CSV file
for root, dirs, files in os.walk(BASE_DIR):
    
    for file in files:
        if file.endswith(".csv"):
            print(root[7:])
# Out:
# 2009q1
# 2009q1
# 2009q1
# 2009q1
# 2009q2
# 2009q2
# 2009q2
# 2009q2
# 2009q3
# 2009q3
# 2009q3
# 2009q3
# 2009q4
# 2009q4
# 2009q4
# 2009q4
# 2010q1
# 2010q1
# 2010q1
# 2010q1
# 2010q2
# 2010q2
# 2010q2
# 2010q2
# 2010q3
# 2010q3
# 2010q3
# 2010q3
# 2010q4
# 2010q4
# 2010q4
# 2010q4
# 2011q1
# 2011q1
# 2011q1
# 2011q1
# 2011q2
# 2011q2
# 2011q2
# 2011q2
# 2011q3
# 2011q3
# 2011q3
# 2011q3
# 2011q4
# 2011q4
# 2011q4
# 2011q4
# 2012q1
# 2012q1
# 2012q1
# 2012q1
# 2012q2
# 2012q2
# 2012q2
# 2012q2
# 2012q3
# 2012q3
# 2012q3
# 2012q3
# 2012q4
# 2012q4
# 2012q4
# 2012q4
# 2013q1
# 2013q1
# 2013q1
# 2013q1
# 2013q2
# 2013q2
# 2013q2
# 2013q2
# 2013q3
# 2013q3
# 2013q3
# 2013q3
# 2013q4
# 2013q4
# 2013q4
# 2013q4
# 2014q1
# 2014q1
# 2014q1
# 2014q1
# 2014q2
# 2014q2
# 2014q2
# 2014q2
# 2014q3
# 2014q3
# 2014q3
# 2014q3
# 2014q4
# 2014q4
# 2014q4
# 2014q4
# 2015q1
# 2015q1
# 2015q1
# 2015q1
# 2015q2
# 2015q2
# 2015q2
# 2015q2
# 2015q3
# 2015q3
# 2015q3
# 2015q3
# 2015q4
# 2015q4
# 2015q4
# ...

# %%
import pandas as pd



df = pd.read_csv("./data/2009q3/sub.txt", sep="\t")

# %%
for i in range(len(df["sic"])):
    if df["sic"][i] == "US":
        print("Found")
